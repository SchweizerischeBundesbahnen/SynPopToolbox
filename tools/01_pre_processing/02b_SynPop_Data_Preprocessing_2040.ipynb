# %% [markdown]
# # SynPop Data Preprocessing

# %% [markdown]
# * **Input**: raw SynPop files produced by FaLC
# * **Output**: Cleaned and optimized pickeled DataFrames
#     * *persons_20XX.pickle.gzip*
#     * *households_20XX.pickle.gzip*
#     * *businesses_20XX.pickle.gzip*

# %%
import logging
import os
import sys
import pandas as pd

# %%
sys.path.append(r'X:\90_Persoenlich\u229285\dev\SynPopToolbox')

# %%
from synpop.preprocessing import SynPopPreprocessor

# %%
# Setting up the logger for this notebook
logging.basicConfig(level=logging.DEBUG, format='%(asctime)s - %(levelname)s - %(name)s: %(message)s')

logger = logging.getLogger('synpop.preprocessing')
logger.setLevel(logging.INFO)  # options: logging.DEBUG, logging.INFO, logging.WARNING

# %% [markdown]
# ## Global Settings

# %%
DATA_DIR = r'\\k13536\mobi\10_Daten\SynPop'
RAW_SYNPOP_DATA_DIR = os.path.join(DATA_DIR, '2040/01_raw')
PROCESSED_DATA_DIR = os.path.join(DATA_DIR, '2040/02_preprocessed')

MOBI_ZONES_SHP_PATH = os.path.join(DATA_DIR, '_mobi_zones/mobi_zones.shp')

BLUR_HOUSEHOLDS = True

YEAR = 2040

# %% [markdown]
# ## Running Preprocessor

# %%
preprocessor = SynPopPreprocessor(RAW_SYNPOP_DATA_DIR, PROCESSED_DATA_DIR, YEAR, MOBI_ZONES_SHP_PATH)

# %% [markdown]
# ### Persons & Households

# %%
persons, households = preprocessor.preprocess_persons_and_households(blur_households=BLUR_HOUSEHOLDS)
# Out:
# 2020-02-17 17:52:22,196 - INFO - synpop.preprocessing: The following columns of persons-2040 have been loaded: ['person_id', 'household_id', 'position_in_hh', 'position_in_bus', 'type_5', 'income', 'sex', 'dbirth', 'education', 'position_in_edu', 'nation', 'mobility', 'car_ownership', 'car_company', 'language', 'type_1', 'type_2', 'type_6']
# 2020-02-17 17:53:02,163 - INFO - numexpr.utils: NumExpr defaulting to 8 threads.
# 2020-02-17 17:53:14,450 - INFO - synpop.preprocessing: The following columns of households-2040 have been loaded: ['household_id', 'location_id', 'type_3', 'xcoord', 'ycoord', 'hcoord_type']
# 2020-02-17 17:53:16,934 - INFO - synpop.preprocessing: Joining households to mobi_zones...
# 2020-02-17 17:53:24,518 - INFO - synpop.preprocessing: Shuffling coordinates for all 4832109 households in 7905 zones.
# 2020-02-17 17:53:40,283 - INFO - synpop.preprocessing: Household coordinates shuffled in 100 / 7905 zones.
# 2020-02-17 17:53:56,861 - INFO - synpop.preprocessing: Household coordinates shuffled in 200 / 7905 zones.
# 2020-02-17 17:54:10,787 - INFO - synpop.preprocessing: Household coordinates shuffled in 300 / 7905 zones.
# 2020-02-17 17:54:24,095 - INFO - synpop.preprocessing: Household coordinates shuffled in 400 / 7905 zones.
# 2020-02-17 17:54:38,407 - INFO - synpop.preprocessing: Household coordinates shuffled in 500 / 7905 zones.
# 2020-02-17 17:54:51,964 - INFO - synpop.preprocessing: Household coordinates shuffled in 600 / 7905 zones.
# 2020-02-17 17:55:04,845 - INFO - synpop.preprocessing: Household coordinates shuffled in 700 / 7905 zones.
# 2020-02-17 17:55:22,556 - INFO - synpop.preprocessing: Household coordinates shuffled in 800 / 7905 zones.
# 2020-02-17 17:55:36,430 - INFO - synpop.preprocessing: Household coordinates shuffled in 900 / 7905 zones.
# 2020-02-17 17:55:54,804 - INFO - synpop.preprocessing: Household coordinates shuffled in 1000 / 7905 zones.
# 2020-02-17 17:56:10,069 - INFO - synpop.preprocessing: Household coordinates shuffled in 1100 / 7905 zones.
# 2020-02-17 17:56:23,386 - INFO - synpop.preprocessing: Household coordinates shuffled in 1200 / 7905 zones.
# 2020-02-17 17:56:35,444 - INFO - synpop.preprocessing: Household coordinates shuffled in 1300 / 7905 zones.
# 2020-02-17 17:56:47,279 - INFO - synpop.preprocessing: Household coordinates shuffled in 1400 / 7905 zones.
# 2020-02-17 17:57:02,214 - INFO - synpop.preprocessing: Household coordinates shuffled in 1500 / 7905 zones.
# 2020-02-17 17:57:15,551 - INFO - synpop.preprocessing: Household coordinates shuffled in 1600 / 7905 zones.
# 2020-02-17 17:57:22,975 - INFO - synpop.preprocessing: Household coordinates shuffled in 1700 / 7905 zones.
# 2020-02-17 17:57:32,852 - INFO - synpop.preprocessing: Household coordinates shuffled in 1800 / 7905 zones.
# 2020-02-17 17:57:41,733 - INFO - synpop.preprocessing: Household coordinates shuffled in 1900 / 7905 zones.
# 2020-02-17 17:57:51,585 - INFO - synpop.preprocessing: Household coordinates shuffled in 2000 / 7905 zones.
# 2020-02-17 17:58:04,558 - INFO - synpop.preprocessing: Household coordinates shuffled in 2100 / 7905 zones.
# 2020-02-17 17:58:12,697 - INFO - synpop.preprocessing: Household coordinates shuffled in 2200 / 7905 zones.
# 2020-02-17 17:58:26,727 - INFO - synpop.preprocessing: Household coordinates shuffled in 2300 / 7905 zones.
# 2020-02-17 17:58:41,486 - INFO - synpop.preprocessing: Household coordinates shuffled in 2400 / 7905 zones.
# 2020-02-17 17:58:50,737 - INFO - synpop.preprocessing: Household coordinates shuffled in 2500 / 7905 zones.
# 2020-02-17 17:59:01,386 - INFO - synpop.preprocessing: Household coordinates shuffled in 2600 / 7905 zones.
# 2020-02-17 17:59:12,435 - INFO - synpop.preprocessing: Household coordinates shuffled in 2700 / 7905 zones.
# 2020-02-17 17:59:20,910 - INFO - synpop.preprocessing: Household coordinates shuffled in 2800 / 7905 zones.
# 2020-02-17 17:59:41,871 - INFO - synpop.preprocessing: Household coordinates shuffled in 2900 / 7905 zones.
# 2020-02-17 17:59:52,616 - INFO - synpop.preprocessing: Household coordinates shuffled in 3000 / 7905 zones.
# 2020-02-17 17:59:59,485 - INFO - synpop.preprocessing: Household coordinates shuffled in 3100 / 7905 zones.
# 2020-02-17 18:00:12,948 - INFO - synpop.preprocessing: Household coordinates shuffled in 3200 / 7905 zones.
# 2020-02-17 18:00:23,707 - INFO - synpop.preprocessing: Household coordinates shuffled in 3300 / 7905 zones.
# 2020-02-17 18:00:32,647 - INFO - synpop.preprocessing: Household coordinates shuffled in 3400 / 7905 zones.
# 2020-02-17 18:00:47,561 - INFO - synpop.preprocessing: Household coordinates shuffled in 3500 / 7905 zones.
# 2020-02-17 18:01:01,543 - INFO - synpop.preprocessing: Household coordinates shuffled in 3600 / 7905 zones.
# 2020-02-17 18:01:12,290 - INFO - synpop.preprocessing: Household coordinates shuffled in 3700 / 7905 zones.
# 2020-02-17 18:01:23,569 - INFO - synpop.preprocessing: Household coordinates shuffled in 3800 / 7905 zones.
# 2020-02-17 18:01:34,364 - INFO - synpop.preprocessing: Household coordinates shuffled in 3900 / 7905 zones.
# 2020-02-17 18:01:41,889 - INFO - synpop.preprocessing: Household coordinates shuffled in 4000 / 7905 zones.
# 2020-02-17 18:01:51,204 - INFO - synpop.preprocessing: Household coordinates shuffled in 4100 / 7905 zones.
# 2020-02-17 18:02:01,016 - INFO - synpop.preprocessing: Household coordinates shuffled in 4200 / 7905 zones.
# 2020-02-17 18:02:16,474 - INFO - synpop.preprocessing: Household coordinates shuffled in 4300 / 7905 zones.
# 2020-02-17 18:02:26,380 - INFO - synpop.preprocessing: Household coordinates shuffled in 4400 / 7905 zones.
# 2020-02-17 18:02:37,003 - INFO - synpop.preprocessing: Household coordinates shuffled in 4500 / 7905 zones.
# 2020-02-17 18:02:46,215 - INFO - synpop.preprocessing: Household coordinates shuffled in 4600 / 7905 zones.
# 2020-02-17 18:02:49,922 - INFO - synpop.preprocessing: Household coordinates shuffled in 4700 / 7905 zones.
# 2020-02-17 18:03:00,199 - INFO - synpop.preprocessing: Household coordinates shuffled in 4800 / 7905 zones.
# 2020-02-17 18:03:11,115 - INFO - synpop.preprocessing: Household coordinates shuffled in 4900 / 7905 zones.
# 2020-02-17 18:03:27,933 - INFO - synpop.preprocessing: Household coordinates shuffled in 5000 / 7905 zones.
# 2020-02-17 18:03:41,178 - INFO - synpop.preprocessing: Household coordinates shuffled in 5100 / 7905 zones.
# 2020-02-17 18:03:50,210 - INFO - synpop.preprocessing: Household coordinates shuffled in 5200 / 7905 zones.
# 2020-02-17 18:04:00,991 - INFO - synpop.preprocessing: Household coordinates shuffled in 5300 / 7905 zones.
# 2020-02-17 18:04:14,111 - INFO - synpop.preprocessing: Household coordinates shuffled in 5400 / 7905 zones.
# 2020-02-17 18:04:24,797 - INFO - synpop.preprocessing: Household coordinates shuffled in 5500 / 7905 zones.
# 2020-02-17 18:04:37,811 - INFO - synpop.preprocessing: Household coordinates shuffled in 5600 / 7905 zones.
# 2020-02-17 18:04:49,757 - INFO - synpop.preprocessing: Household coordinates shuffled in 5700 / 7905 zones.
# 2020-02-17 18:04:57,935 - INFO - synpop.preprocessing: Household coordinates shuffled in 5800 / 7905 zones.
# 2020-02-17 18:05:07,991 - INFO - synpop.preprocessing: Household coordinates shuffled in 5900 / 7905 zones.
# 2020-02-17 18:05:17,355 - INFO - synpop.preprocessing: Household coordinates shuffled in 6000 / 7905 zones.
# 2020-02-17 18:05:25,813 - INFO - synpop.preprocessing: Household coordinates shuffled in 6100 / 7905 zones.
# 2020-02-17 18:05:34,399 - INFO - synpop.preprocessing: Household coordinates shuffled in 6200 / 7905 zones.
# 2020-02-17 18:05:46,961 - INFO - synpop.preprocessing: Household coordinates shuffled in 6300 / 7905 zones.
# 2020-02-17 18:05:57,528 - INFO - synpop.preprocessing: Household coordinates shuffled in 6400 / 7905 zones.
# 2020-02-17 18:06:10,615 - INFO - synpop.preprocessing: Household coordinates shuffled in 6500 / 7905 zones.
# 2020-02-17 18:06:24,437 - INFO - synpop.preprocessing: Household coordinates shuffled in 6600 / 7905 zones.
# 2020-02-17 18:06:38,608 - INFO - synpop.preprocessing: Household coordinates shuffled in 6700 / 7905 zones.
# 2020-02-17 18:06:48,470 - INFO - synpop.preprocessing: Household coordinates shuffled in 6800 / 7905 zones.
# 2020-02-17 18:07:00,379 - INFO - synpop.preprocessing: Household coordinates shuffled in 6900 / 7905 zones.
# 2020-02-17 18:07:09,567 - INFO - synpop.preprocessing: Household coordinates shuffled in 7000 / 7905 zones.
# 2020-02-17 18:07:20,282 - INFO - synpop.preprocessing: Household coordinates shuffled in 7100 / 7905 zones.
# 2020-02-17 18:07:30,994 - INFO - synpop.preprocessing: Household coordinates shuffled in 7200 / 7905 zones.
# 2020-02-17 18:07:39,701 - INFO - synpop.preprocessing: Household coordinates shuffled in 7300 / 7905 zones.
# 2020-02-17 18:07:50,286 - INFO - synpop.preprocessing: Household coordinates shuffled in 7400 / 7905 zones.
# 2020-02-17 18:08:05,305 - INFO - synpop.preprocessing: Household coordinates shuffled in 7500 / 7905 zones.
# 2020-02-17 18:08:25,543 - INFO - synpop.preprocessing: Household coordinates shuffled in 7600 / 7905 zones.
# 2020-02-17 18:08:39,734 - INFO - synpop.preprocessing: Household coordinates shuffled in 7700 / 7905 zones.
# 2020-02-17 18:08:58,143 - INFO - synpop.preprocessing: Household coordinates shuffled in 7800 / 7905 zones.
# 2020-02-17 18:09:02,617 - INFO - synpop.preprocessing: Household coordinates shuffled in 7900 / 7905 zones.
# 2020-02-17 18:09:16,321 - INFO - synpop.preprocessing: Coordinates of 4832109 households in 7905 zones have been blurred.
# 2020-02-17 18:09:16,323 - WARNING - synpop.preprocessing: No solution found for 144 zones where some households kept their original coordinates. For example: [171101010 102402022  26101194  35101052 662303009]
# 2020-02-17 18:09:16,325 - WARNING - synpop.preprocessing: In total, 7133 households kept their original coordinates.For example: [204424 228628 282150 286385 289600]
# 2020-02-17 18:09:33,986 - INFO - synpop.preprocessing: Joining persons to households...
# 2020-02-17 18:30:06,149 - INFO - synpop.preprocessing: Pre-processed "persons" table has been saved to: \\k13536\mobi\10_Daten\SynPop\2040/02_preprocessed\persons_2040.pickle.gzip
# 2020-02-17 18:34:40,791 - INFO - synpop.preprocessing: Pre-processed "households" table has been saved to: \\k13536\mobi\10_Daten\SynPop\2040/02_preprocessed\households_2040.pickle.gzip

# %% [markdown]
# **Persons**

# %%
persons.shape
# Out:
# (10037464, 33)

# %%
persons.columns
# Out:
# Index(['person_id', 'household_id', 'position_in_hh', 'position_in_bus',
#        'income', 'sex', 'education', 'position_in_edu', 'nation', 'mobility',
#        'car_ownership', 'car_company', 'language', 'business_sector',
#        'level_of_employment', 'corrected_position_in_bus',
#        'corrected_level_of_employment', 'has_ga', 'has_ht', 'has_va',
#        'car_available', 'year_of_birth', 'age', 'location_id',
#        'household_model', 'hcoord_type', 'KT', 'N_KT', 'ID_Gem', 'N_Gem',
#        'KT_full', 'xcoord', 'ycoord'],
#       dtype='object')

# %%
persons.head()
# Out:
#    person_id  household_id position_in_hh position_in_bus  income sex  \
# 0          1             2        partner        employee   33259   F
# 1          2             6        partner      unemployed   32430   M
# 2          4       7241770        partner      management   87871   M
# 3          5             8        partner             ceo  268189   M
# 4          6             8          other        employee   47514   F
#
#    education position_in_edu     nation       mobility  ...  location_id  \
# 0     no_edu            null     africa            car  ...    220601003
# 1     no_edu            null  so-europe       car & va  ...     24301026
# 2        uni            null     africa            car  ...    662101042
# 3     no_edu            null  so-europe  car & va & ht  ...     24301003
# 4  secondary            null  so-europe            car  ...     24301003
#
#       household_model                hcoord_type  KT  N_KT ID_Gem     N_Gem  \
# 0  pair_with_children  with_original_coordinates  10    FR   2206     Marly
# 1  pair_with_children  with_original_coordinates   1    ZH    243  Dietikon
# 2  pair_with_children              not_available  25    GE   6621    Genève
# 3  pair_with_children  with_original_coordinates   1    ZH    243  Dietikon
# 4  pair_with_children  with_original_coordinates   1    ZH    243  Dietikon
#
#                KT_full     xcoord     ycoord
# 0  Fribourg / Freiburg  2578625.0  1181241.0
# 1               Zürich  2674302.0  1250112.0
# 2               Genève  2499558.0  1116999.0
# 3               Zürich  2671941.0  1250565.0
# 4               Zürich  2671941.0  1250565.0
#
# [5 rows x 33 columns]

# %% [markdown]
# **Households**

# %%
households.shape
# Out:
# (4832109, 11)

# %%
households.columns
# Out:
# Index(['household_id', 'location_id', 'household_model', 'hcoord_type', 'KT',
#        'N_KT', 'ID_Gem', 'N_Gem', 'KT_full', 'xcoord', 'ycoord'],
#       dtype='object')

# %%
households.head()
# Out:
#    household_id  location_id     household_model                hcoord_type  \
# 0             1    646101003              single  with_original_coordinates
# 1             2    220601003  pair_with_children  with_original_coordinates
# 2             6     24301026  pair_with_children  with_original_coordinates
# 3             8     24301003  pair_with_children  with_original_coordinates
# 4             9     23001046  pair_with_children  with_original_coordinates
#
#    KT N_KT  ID_Gem       N_Gem              KT_full     xcoord     ycoord
# 0  24   NE    6461     La Tène            Neuchâtel  2567121.0  1206425.0
# 1  10   FR    2206       Marly  Fribourg / Freiburg  2578625.0  1181241.0
# 2   1   ZH     243    Dietikon               Zürich  2674302.0  1250112.0
# 3   1   ZH     243    Dietikon               Zürich  2671941.0  1250565.0
# 4   1   ZH     230  Winterthur               Zürich  2697902.0  1261991.0

# %% [markdown]
# ### Businesses

# %%
businesses = preprocessor.preprocess_businesses()
# Out:
# 2020-02-17 18:34:48,514 - INFO - synpop.preprocessing: The following columns of businesses-2040 have been loaded: ['business_id', 'location_id', 'type_1', 'type_2', 'type_3', 'dfoundation', 'nr_of_jobs', 'cb_nr_of_jobs', 'fte', 'cb_fte', 'nr_of_cars', 'school_type', 'xcoord', 'ycoord', 'bcoord_type']
# 2020-02-17 18:34:51,378 - INFO - synpop.preprocessing: Joining households to mobi_zones...
# 2020-02-17 18:34:54,604 - WARNING - synpop.preprocessing: 87 businesses have not been joined to a mobi-zone!
# 2020-02-17 18:36:20,666 - INFO - synpop.preprocessing: Pre-processed "businesses" table has been saved to: \\k13536\mobi\10_Daten\SynPop\2040/02_preprocessed\businesses_2040.pickle.gzip

# %%
businesses.shape
# Out:
# (1506689, 20)

# %%
businesses.columns
# Out:
# Index(['business_id', 'location_id', 'sector', 'legal_form', 'noga_code',
#        'jobs_ch', 'fte_ch', 'jobs_cb', 'fte_cb', 'nr_of_cars', 'school_type',
#        'xcoord', 'ycoord', 'bcoord_type', 'year_of_foundation', 'KT', 'N_KT',
#        'ID_Gem', 'N_Gem', 'KT_full'],
#       dtype='object')

# %%
businesses.head()
# Out:
#    business_id  location_id          sector            legal_form  noga_code  \
# 0            4    105201003     agriculture          partnerships      16200
# 1            6    671101002     services fC             companies     813000
# 2           11    560601001  other services          partnerships     960900
# 3           13    641201001     services fC  branch_establishment     813000
# 4           17    219701003  other services          partnerships     960900
#
#    jobs_ch  fte_ch  jobs_cb  fte_cb  nr_of_cars school_type     xcoord  \
# 0        1    0.89        0     0.0           0   no_school  2668716.0
# 1        7    6.39        0     0.0           2   no_school  2592635.0
# 2        1    0.81        0     0.0           0   no_school  2541920.0
# 3        2    2.00        0     0.0           0   no_school  2558206.0
# 4        1    0.29        0     0.0           0   no_school  2576667.0
#
#       ycoord    bcoord_type  year_of_foundation    KT N_KT  ID_Gem     N_Gem  \
# 0  1215690.0  not_available                2016   3.0   LU  1052.0  Buchrain
# 1  1245854.0  not_available                2007  26.0   JU  6711.0  Delémont
# 2  1150745.0  not_available                1988  22.0   VD  5606.0     Lutry
# 3  1204259.0  not_available                2011  24.0   NE  6412.0    Peseux
# 4  1184358.0  not_available                2009  10.0   FR  2197.0  Givisiez
#
#                KT_full
# 0               Luzern
# 1                 Jura
# 2                 Vaud
# 3            Neuchâtel
# 4  Fribourg / Freiburg

# %% [markdown]
# ## Export Notebook to HTML

# %%
### Write notebook to a html file
# !jupyter nbconvert --to html 02b_SynPop_Data_Preprocessing_2040.ipynb
# Out:
# [NbConvertApp] Converting notebook 02b_SynPop_Data_Preprocessing_2040.ipynb to html
# [NbConvertApp] Writing 306746 bytes to 02b_SynPop_Data_Preprocessing_2040.html
