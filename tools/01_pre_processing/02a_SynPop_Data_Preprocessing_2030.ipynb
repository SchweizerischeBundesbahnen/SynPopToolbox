# %% [markdown]
# # SynPop Data Preprocessing

# %% [markdown]
# * **Input**: raw SynPop files produced by FaLC
# * **Output**: Cleaned and optimized pickeled DataFrames
#     * *persons_20XX.pickle.gzip*
#     * *households_20XX.pickle.gzip*
#     * *businesses_20XX.pickle.gzip*

# %%
import logging
import os
import sys
import pandas as pd

# %%
sys.path.append(r'X:\90_Persoenlich\u229285\dev\SynPopToolbox')

# %%
from synpop.preprocessing import SynPopPreprocessor

# %%
# Setting up the logger for this notebook
logging.basicConfig(level=logging.DEBUG, format='%(asctime)s - %(levelname)s - %(name)s: %(message)s')

logger = logging.getLogger('synpop.preprocessing')
logger.setLevel(logging.INFO)  # options: logging.DEBUG, logging.INFO, logging.WARNING

# %% [markdown]
# ## Global Settings

# %%
DATA_DIR = r'\\k13536\mobi\10_Daten\SynPop'
RAW_SYNPOP_DATA_DIR = os.path.join(DATA_DIR, '2030/01_raw')
PROCESSED_DATA_DIR = os.path.join(DATA_DIR, '2030/02_preprocessed')

MOBI_ZONES_SHP_PATH = os.path.join(DATA_DIR, '_mobi_zones/mobi_zones.shp')

BLUR_HOUSEHOLDS = True

YEAR = 2030

# %% [markdown]
# ## Running Preprocessor

# %%
preprocessor = SynPopPreprocessor(RAW_SYNPOP_DATA_DIR, PROCESSED_DATA_DIR, YEAR, MOBI_ZONES_SHP_PATH)

# %% [markdown]
# ### Persons & Households

# %%
persons, households = preprocessor.preprocess_persons_and_households(blur_households=BLUR_HOUSEHOLDS)
# Out:
# 2020-02-17 17:50:33,345 - INFO - synpop.preprocessing: The following columns of persons-2030 have been loaded: ['person_id', 'household_id', 'position_in_hh', 'position_in_bus', 'type_5', 'income', 'sex', 'dbirth', 'education', 'position_in_edu', 'nation', 'mobility', 'car_ownership', 'car_company', 'language', 'type_1', 'type_2', 'type_6']
# 2020-02-17 17:51:11,758 - INFO - numexpr.utils: NumExpr defaulting to 8 threads.
# 2020-02-17 17:51:26,876 - INFO - synpop.preprocessing: The following columns of households-2030 have been loaded: ['household_id', 'location_id', 'type_3', 'xcoord', 'ycoord', 'hcoord_type']
# 2020-02-17 17:51:29,151 - INFO - synpop.preprocessing: Joining households to mobi_zones...
# 2020-02-17 17:51:36,152 - INFO - synpop.preprocessing: Shuffling coordinates for all 4459562 households in 7904 zones.
# 2020-02-17 17:51:48,774 - INFO - synpop.preprocessing: Household coordinates shuffled in 100 / 7904 zones.
# 2020-02-17 17:52:01,348 - INFO - synpop.preprocessing: Household coordinates shuffled in 200 / 7904 zones.
# 2020-02-17 17:52:12,120 - INFO - synpop.preprocessing: Household coordinates shuffled in 300 / 7904 zones.
# 2020-02-17 17:52:23,523 - INFO - synpop.preprocessing: Household coordinates shuffled in 400 / 7904 zones.
# 2020-02-17 17:52:35,046 - INFO - synpop.preprocessing: Household coordinates shuffled in 500 / 7904 zones.
# 2020-02-17 17:52:47,989 - INFO - synpop.preprocessing: Household coordinates shuffled in 600 / 7904 zones.
# 2020-02-17 17:52:58,409 - INFO - synpop.preprocessing: Household coordinates shuffled in 700 / 7904 zones.
# 2020-02-17 17:53:13,435 - INFO - synpop.preprocessing: Household coordinates shuffled in 800 / 7904 zones.
# 2020-02-17 17:53:24,419 - INFO - synpop.preprocessing: Household coordinates shuffled in 900 / 7904 zones.
# 2020-02-17 17:53:40,099 - INFO - synpop.preprocessing: Household coordinates shuffled in 1000 / 7904 zones.
# 2020-02-17 17:53:52,395 - INFO - synpop.preprocessing: Household coordinates shuffled in 1100 / 7904 zones.
# 2020-02-17 17:54:03,920 - INFO - synpop.preprocessing: Household coordinates shuffled in 1200 / 7904 zones.
# 2020-02-17 17:54:14,075 - INFO - synpop.preprocessing: Household coordinates shuffled in 1300 / 7904 zones.
# 2020-02-17 17:54:23,996 - INFO - synpop.preprocessing: Household coordinates shuffled in 1400 / 7904 zones.
# 2020-02-17 17:54:36,883 - INFO - synpop.preprocessing: Household coordinates shuffled in 1500 / 7904 zones.
# 2020-02-17 17:54:47,485 - INFO - synpop.preprocessing: Household coordinates shuffled in 1600 / 7904 zones.
# 2020-02-17 17:54:54,208 - INFO - synpop.preprocessing: Household coordinates shuffled in 1700 / 7904 zones.
# 2020-02-17 17:55:02,690 - INFO - synpop.preprocessing: Household coordinates shuffled in 1800 / 7904 zones.
# 2020-02-17 17:55:10,069 - INFO - synpop.preprocessing: Household coordinates shuffled in 1900 / 7904 zones.
# 2020-02-17 17:55:18,720 - INFO - synpop.preprocessing: Household coordinates shuffled in 2000 / 7904 zones.
# 2020-02-17 17:55:30,442 - INFO - synpop.preprocessing: Household coordinates shuffled in 2100 / 7904 zones.
# 2020-02-17 17:55:37,858 - INFO - synpop.preprocessing: Household coordinates shuffled in 2200 / 7904 zones.
# 2020-02-17 17:55:50,419 - INFO - synpop.preprocessing: Household coordinates shuffled in 2300 / 7904 zones.
# 2020-02-17 17:56:04,403 - INFO - synpop.preprocessing: Household coordinates shuffled in 2400 / 7904 zones.
# 2020-02-17 17:56:12,770 - INFO - synpop.preprocessing: Household coordinates shuffled in 2500 / 7904 zones.
# 2020-02-17 17:56:21,534 - INFO - synpop.preprocessing: Household coordinates shuffled in 2600 / 7904 zones.
# 2020-02-17 17:56:30,968 - INFO - synpop.preprocessing: Household coordinates shuffled in 2700 / 7904 zones.
# 2020-02-17 17:56:38,368 - INFO - synpop.preprocessing: Household coordinates shuffled in 2800 / 7904 zones.
# 2020-02-17 17:56:51,720 - INFO - synpop.preprocessing: Household coordinates shuffled in 2900 / 7904 zones.
# 2020-02-17 17:57:01,417 - INFO - synpop.preprocessing: Household coordinates shuffled in 3000 / 7904 zones.
# 2020-02-17 17:57:07,887 - INFO - synpop.preprocessing: Household coordinates shuffled in 3100 / 7904 zones.
# 2020-02-17 17:57:17,714 - INFO - synpop.preprocessing: Household coordinates shuffled in 3200 / 7904 zones.
# 2020-02-17 17:57:26,572 - INFO - synpop.preprocessing: Household coordinates shuffled in 3300 / 7904 zones.
# 2020-02-17 17:57:34,148 - INFO - synpop.preprocessing: Household coordinates shuffled in 3400 / 7904 zones.
# 2020-02-17 17:57:48,201 - INFO - synpop.preprocessing: Household coordinates shuffled in 3500 / 7904 zones.
# 2020-02-17 17:58:04,439 - INFO - synpop.preprocessing: Household coordinates shuffled in 3600 / 7904 zones.
# 2020-02-17 17:58:16,275 - INFO - synpop.preprocessing: Household coordinates shuffled in 3700 / 7904 zones.
# 2020-02-17 17:58:27,069 - INFO - synpop.preprocessing: Household coordinates shuffled in 3800 / 7904 zones.
# 2020-02-17 17:58:37,667 - INFO - synpop.preprocessing: Household coordinates shuffled in 3900 / 7904 zones.
# 2020-02-17 17:58:44,877 - INFO - synpop.preprocessing: Household coordinates shuffled in 4000 / 7904 zones.
# 2020-02-17 17:58:54,549 - INFO - synpop.preprocessing: Household coordinates shuffled in 4100 / 7904 zones.
# 2020-02-17 17:59:05,386 - INFO - synpop.preprocessing: Household coordinates shuffled in 4200 / 7904 zones.
# 2020-02-17 17:59:18,895 - INFO - synpop.preprocessing: Household coordinates shuffled in 4300 / 7904 zones.
# 2020-02-17 17:59:28,058 - INFO - synpop.preprocessing: Household coordinates shuffled in 4400 / 7904 zones.
# 2020-02-17 17:59:37,032 - INFO - synpop.preprocessing: Household coordinates shuffled in 4500 / 7904 zones.
# 2020-02-17 17:59:45,035 - INFO - synpop.preprocessing: Household coordinates shuffled in 4600 / 7904 zones.
# 2020-02-17 17:59:48,684 - INFO - synpop.preprocessing: Household coordinates shuffled in 4700 / 7904 zones.
# 2020-02-17 17:59:59,080 - INFO - synpop.preprocessing: Household coordinates shuffled in 4800 / 7904 zones.
# 2020-02-17 18:00:09,612 - INFO - synpop.preprocessing: Household coordinates shuffled in 4900 / 7904 zones.
# 2020-02-17 18:00:24,025 - INFO - synpop.preprocessing: Household coordinates shuffled in 5000 / 7904 zones.
# 2020-02-17 18:00:35,234 - INFO - synpop.preprocessing: Household coordinates shuffled in 5100 / 7904 zones.
# 2020-02-17 18:00:43,079 - INFO - synpop.preprocessing: Household coordinates shuffled in 5200 / 7904 zones.
# 2020-02-17 18:00:52,105 - INFO - synpop.preprocessing: Household coordinates shuffled in 5300 / 7904 zones.
# 2020-02-17 18:01:02,690 - INFO - synpop.preprocessing: Household coordinates shuffled in 5400 / 7904 zones.
# 2020-02-17 18:01:11,669 - INFO - synpop.preprocessing: Household coordinates shuffled in 5500 / 7904 zones.
# 2020-02-17 18:01:22,018 - INFO - synpop.preprocessing: Household coordinates shuffled in 5600 / 7904 zones.
# 2020-02-17 18:01:30,641 - INFO - synpop.preprocessing: Household coordinates shuffled in 5700 / 7904 zones.
# 2020-02-17 18:01:37,391 - INFO - synpop.preprocessing: Household coordinates shuffled in 5800 / 7904 zones.
# 2020-02-17 18:01:45,403 - INFO - synpop.preprocessing: Household coordinates shuffled in 5900 / 7904 zones.
# 2020-02-17 18:01:52,087 - INFO - synpop.preprocessing: Household coordinates shuffled in 6000 / 7904 zones.
# 2020-02-17 18:01:58,727 - INFO - synpop.preprocessing: Household coordinates shuffled in 6100 / 7904 zones.
# 2020-02-17 18:02:06,090 - INFO - synpop.preprocessing: Household coordinates shuffled in 6200 / 7904 zones.
# 2020-02-17 18:02:15,071 - INFO - synpop.preprocessing: Household coordinates shuffled in 6300 / 7904 zones.
# 2020-02-17 18:02:24,554 - INFO - synpop.preprocessing: Household coordinates shuffled in 6400 / 7904 zones.
# 2020-02-17 18:02:35,964 - INFO - synpop.preprocessing: Household coordinates shuffled in 6500 / 7904 zones.
# 2020-02-17 18:02:45,140 - INFO - synpop.preprocessing: Household coordinates shuffled in 6600 / 7904 zones.
# 2020-02-17 18:02:54,411 - INFO - synpop.preprocessing: Household coordinates shuffled in 6700 / 7904 zones.
# 2020-02-17 18:03:02,534 - INFO - synpop.preprocessing: Household coordinates shuffled in 6800 / 7904 zones.
# 2020-02-17 18:03:11,542 - INFO - synpop.preprocessing: Household coordinates shuffled in 6900 / 7904 zones.
# 2020-02-17 18:03:18,713 - INFO - synpop.preprocessing: Household coordinates shuffled in 7000 / 7904 zones.
# 2020-02-17 18:03:27,621 - INFO - synpop.preprocessing: Household coordinates shuffled in 7100 / 7904 zones.
# 2020-02-17 18:03:35,295 - INFO - synpop.preprocessing: Household coordinates shuffled in 7200 / 7904 zones.
# 2020-02-17 18:03:43,117 - INFO - synpop.preprocessing: Household coordinates shuffled in 7300 / 7904 zones.
# 2020-02-17 18:03:52,724 - INFO - synpop.preprocessing: Household coordinates shuffled in 7400 / 7904 zones.
# 2020-02-17 18:04:03,945 - INFO - synpop.preprocessing: Household coordinates shuffled in 7500 / 7904 zones.
# 2020-02-17 18:04:20,596 - INFO - synpop.preprocessing: Household coordinates shuffled in 7600 / 7904 zones.
# 2020-02-17 18:04:32,861 - INFO - synpop.preprocessing: Household coordinates shuffled in 7700 / 7904 zones.
# 2020-02-17 18:04:48,795 - INFO - synpop.preprocessing: Household coordinates shuffled in 7800 / 7904 zones.
# 2020-02-17 18:04:53,329 - INFO - synpop.preprocessing: Household coordinates shuffled in 7900 / 7904 zones.
# 2020-02-17 18:05:04,554 - INFO - synpop.preprocessing: Coordinates of 4459562 households in 7904 zones have been blurred.
# 2020-02-17 18:05:04,556 - WARNING - synpop.preprocessing: No solution found for 142 zones where some households kept their original coordinates. For example: [171101010  24701020  26101019  26101194 170801002]
# 2020-02-17 18:05:04,557 - WARNING - synpop.preprocessing: In total, 6269 households kept their original coordinates.For example: [111192 126498 159674 235966 239381]
# 2020-02-17 18:05:21,902 - INFO - synpop.preprocessing: Joining persons to households...
# 2020-02-17 18:27:26,724 - INFO - synpop.preprocessing: Pre-processed "persons" table has been saved to: \\k13536\mobi\10_Daten\SynPop\2030/02_preprocessed\persons_2030.pickle.gzip
# 2020-02-17 18:31:52,672 - INFO - synpop.preprocessing: Pre-processed "households" table has been saved to: \\k13536\mobi\10_Daten\SynPop\2030/02_preprocessed\households_2030.pickle.gzip

# %% [markdown]
# **Persons**

# %%
persons.shape
# Out:
# (9557232, 33)

# %%
persons.columns
# Out:
# Index(['person_id', 'household_id', 'position_in_hh', 'position_in_bus',
#        'income', 'sex', 'education', 'position_in_edu', 'nation', 'mobility',
#        'car_ownership', 'car_company', 'language', 'business_sector',
#        'level_of_employment', 'corrected_position_in_bus',
#        'corrected_level_of_employment', 'has_ga', 'has_ht', 'has_va',
#        'car_available', 'year_of_birth', 'age', 'location_id',
#        'household_model', 'hcoord_type', 'KT', 'N_KT', 'ID_Gem', 'N_Gem',
#        'KT_full', 'xcoord', 'ycoord'],
#       dtype='object')

# %%
persons.head()
# Out:
#    person_id  household_id position_in_hh position_in_bus  income sex  \
# 0          1             2        partner      management   39876   F
# 1          2             6        partner      unemployed   32430   M
# 2          4       7241770        partner      management   85997   M
# 3          5             8        partner        employee   41800   M
# 4          6             8          other        employee   41779   F
#
#    education position_in_edu     nation  mobility  ...  location_id  \
# 0     no_edu            null     africa  car & va  ...    220601003
# 1     no_edu            null  so-europe       car  ...     24301026
# 2        uni            null     africa  car & ht  ...    662101108
# 3     no_edu            null  so-europe  car & ht  ...     24301003
# 4  secondary            null  so-europe       car  ...     24301003
#
#       household_model                hcoord_type  KT  N_KT ID_Gem     N_Gem  \
# 0                pair  with_original_coordinates  10    FR   2206     Marly
# 1  pair_with_children  with_original_coordinates   1    ZH    243  Dietikon
# 2  pair_with_children              not_available  25    GE   6621    Genève
# 3  pair_with_children  with_original_coordinates   1    ZH    243  Dietikon
# 4  pair_with_children  with_original_coordinates   1    ZH    243  Dietikon
#
#                KT_full     xcoord     ycoord
# 0  Fribourg / Freiburg  2578223.0  1181572.0
# 1               Zürich  2674342.0  1250164.0
# 2               Genève  2501260.0  1117576.0
# 3               Zürich  2672017.0  1250638.0
# 4               Zürich  2672017.0  1250638.0
#
# [5 rows x 33 columns]

# %% [markdown]
# **Households**

# %%
households.shape
# Out:
# (4459562, 11)

# %%
households.columns
# Out:
# Index(['household_id', 'location_id', 'household_model', 'hcoord_type', 'KT',
#        'N_KT', 'ID_Gem', 'N_Gem', 'KT_full', 'xcoord', 'ycoord'],
#       dtype='object')

# %%
households.head()
# Out:
#    household_id  location_id     household_model                hcoord_type  \
# 0             1    646101003              single  with_original_coordinates
# 1             2    220601003                pair  with_original_coordinates
# 2             6     24301026  pair_with_children  with_original_coordinates
# 3             8     24301003  pair_with_children  with_original_coordinates
# 4             9     23001067  pair_with_children  with_original_coordinates
#
#    KT N_KT  ID_Gem       N_Gem              KT_full     xcoord     ycoord
# 0  24   NE    6461     La Tène            Neuchâtel  2566976.0  1206344.0
# 1  10   FR    2206       Marly  Fribourg / Freiburg  2578223.0  1181572.0
# 2   1   ZH     243    Dietikon               Zürich  2674342.0  1250164.0
# 3   1   ZH     243    Dietikon               Zürich  2672017.0  1250638.0
# 4   1   ZH     230  Winterthur               Zürich  2699726.0  1260667.0

# %% [markdown]
# ### Businesses

# %%
businesses = preprocessor.preprocess_businesses()
# Out:
# 2020-02-17 18:32:00,215 - INFO - synpop.preprocessing: The following columns of businesses-2030 have been loaded: ['business_id', 'location_id', 'type_1', 'type_2', 'type_3', 'dfoundation', 'nr_of_jobs', 'cb_nr_of_jobs', 'fte', 'cb_fte', 'nr_of_cars', 'school_type', 'xcoord', 'ycoord', 'bcoord_type']
# 2020-02-17 18:32:02,672 - INFO - synpop.preprocessing: Joining households to mobi_zones...
# 2020-02-17 18:32:05,526 - WARNING - synpop.preprocessing: 85 businesses have not been joined to a mobi-zone!
# 2020-02-17 18:33:21,474 - INFO - synpop.preprocessing: Pre-processed "businesses" table has been saved to: \\k13536\mobi\10_Daten\SynPop\2030/02_preprocessed\businesses_2030.pickle.gzip

# %%
businesses.shape
# Out:
# (1230484, 20)

# %%
businesses.columns
# Out:
# Index(['business_id', 'location_id', 'sector', 'legal_form', 'noga_code',
#        'jobs_ch', 'fte_ch', 'jobs_cb', 'fte_cb', 'nr_of_cars', 'school_type',
#        'xcoord', 'ycoord', 'bcoord_type', 'year_of_foundation', 'KT', 'N_KT',
#        'ID_Gem', 'N_Gem', 'KT_full'],
#       dtype='object')

# %%
businesses.head()
# Out:
#    business_id  location_id       sector            legal_form  noga_code  \
# 0            4    105201003  agriculture          partnerships      16200
# 1            5    643201001  agriculture          partnerships      14300
# 2            6    664101002  services fC             companies     813000
# 3            7    469101004  services fC             companies          0
# 4           10    662101098  services fC  branch_establishment     813000
#
#    jobs_ch  fte_ch  jobs_cb  fte_cb  nr_of_cars school_type     xcoord  \
# 0        1    0.89        0     0.0           0   no_school  2668716.0
# 1        1    0.50        0     0.0           0   no_school  2539429.0
# 2        7    6.39        0     0.0           2   no_school  2500207.0
# 3        3    2.17        0     0.0           3   no_school  2735443.0
# 4        4    3.20        1     0.8           0   no_school  2500902.0
#
#       ycoord    bcoord_type  year_of_foundation    KT N_KT  ID_Gem  \
# 0  1215690.0  not_available                2016   3.0   LU  1052.0
# 1  1205253.0  not_available                2014  24.0   NE  6432.0
# 2  1113309.0  not_available                2007  25.0   GE  6641.0
# 3  1276437.0  not_available                1995  20.0   TG  4691.0
# 4  1117633.0  not_available                2011  25.0   GE  6621.0
#
#            N_Gem    KT_full
# 0       Buchrain     Luzern
# 1     La Brévine  Neuchâtel
# 2        Troinex     Genève
# 3  Münsterlingen    Thurgau
# 4         Genève     Genève

# %% [markdown]
# ## Exporting the current Notebook to HTML

# %%
### Write notebook to a html file
# !jupyter nbconvert --to html 02a_SynPop_Data_Preprocessing_2030.ipynb
# Out:
# [NbConvertApp] Converting notebook 02a_SynPop_Data_Preprocessing_2030.ipynb to html
# [NbConvertApp] Writing 306478 bytes to 02a_SynPop_Data_Preprocessing_2030.html
